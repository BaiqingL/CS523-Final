# %%
import numpy as np
import matplotlib.pyplot as plt
 
# data to be plotted
x = np.arange(1, 11)

 
# plotting
plt.title("Model accuracy")
plt.xlabel("X axis")
plt.ylabel("Y axis")
plt.plot(x)
plt.show()
